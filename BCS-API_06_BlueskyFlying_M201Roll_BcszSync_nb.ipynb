# %% [markdown]
# # Combining LabView BCS with Bluesky

# %% [markdown]
# ## Overview

# %% [markdown]
# This notebook demonstrates how the LabView Beamline Control System API can be used to implement a "Single Motor Scan" as an `ophyd` device. Furthermore, this "Single Motor Scan" device can be initiated by the `bluesky` Run Engine as a `fly` plan with data avaliable in a bluesky run document.

# %% [markdown]
# ### Brief Summary
#
# The bluesky `fly` plan will cede control to an `ophyd` "[Fly-able Interface](http://nsls-ii.github.io/ophyd/architecture.html#fly-able-interface)" (e.g., [FlyerInterface](https://github.com/bluesky/ophyd/blob/dd4b3e389a0202ecacce39fc3965d703c616b0d4/ophyd/flyers.py#L17)) to collect data asynchronously, and then return data as "[event](https://blueskyproject.io/event-model/data-model.html#event-document)" documents.
#
# The "Fly-able Interface" must:
#
# 1. `kickoff()` the scan
# 2. `complete()` data collection for the scan
# 3. `describe_collect()`: provide a descriptor for the data that is being collected
# 4. `collect()`: yield event document(s) that contain the data
#
# More details about this concept of embedding external control system scans into bluesky can be found in [this example notebook](https://github.com/BCDA-APS/bluesky_training/blob/31-sscan-1D-as-flyer/sscan_1d_flyer.ipynb).
#
# This example uses a _synchronous/blocking_ version of the BCS-API library (BCSz_sync.py), which is otherwise identical to the asynchronous version (BCSz.py). The blocking version was created because the bluesky Run Engine does not currently use `asyncio` `await` directive for the Fly-able interface methods.

# %% [markdown]
# ## Credits
#
# This example builds heavily upon two recently published works, as well as the many developers and contributors to the bluesky and BCS projects.
#
# * [BCS-API](http://bcsapi.als.lbl.gov:3080): ZeroMQ library and python bindings (BCSz.py) developed by [Damon English](https://github.com/daenglis) for interfacing with the Advanced Light Source's BCS control system.
# * [`sscan as 1D Flyer`](https://github.com/BCDA-APS/bluesky_training/blob/31-sscan-1D-as-flyer/sscan_1d_flyer.ipynb) example published by [Pete Jemian](https://github.com/prjemian) to demonstrate how the bluesky fly plan can be used to initiate scans and report data from external control systems (in that case, the EPICS sscan record).

# %% [markdown]
# # Prepare the notebook settings

# %%
from IPython.core.interactiveshell import InteractiveShell

# pretty print all cell's output and not just the last one
InteractiveShell.ast_node_interactivity = "all"

# %%
import matplotlib
# %matplotlib notebook

# %%
# %%javascript
# var kernel = IPython.notebook.kernel;
# var thename = window.document.getElementById("notebook_name").innerHTML;
# var command = "theNotebook = " + "'"+thename+"'";
# kernel.execute(command);

# %%
try:
    theNotebook
except NameError as e:
    theNotebook = "BCS-API_05_BlueskyFlying_M201Roll_BcszSync"
    theNotebook
# Out:
# 'BCS-API_05_BlueskyFlying_M201Roll_BcszSync_nb'

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# %% [markdown]
# # Setup bluesky

# %%
from bluesky import RunEngine

RE = RunEngine({})

# %%
from bluesky.callbacks.best_effort import BestEffortCallback
bec = BestEffortCallback()

# Send all metadata/data captured to the BestEffortCallback.
bec_token = RE.subscribe(bec)
bec.enable_table()  # Print hinted readings from the ‘primary’ stream in a LiveTable

# Make plots update live while scans run.
from bluesky.utils import install_kicker
install_kicker()

# %%
from dotenv import load_dotenv

load_dotenv()  # import environment variables from .env
# Out:
# True

# %%
from databroker import Broker
db = Broker.named('TEST')

# Insert all metadata/data captured into db.
RE.subscribe(db.insert)
# Out:
# 1

# %%
from bluesky.utils import ProgressBarManager
RE.waiting_hook = ProgressBarManager()

# %%
RE.md['notebook'] = theNotebook
RE.md
# Out:
# {'versions': {'ophyd': '1.6.1', 'bluesky': '1.6.7'},
#  'notebook': 'BCS-API_05_BlueskyFlying_M201Roll_BcszSync_nb'}

# %% [markdown]
# # Setup BCS-API

# %%
# These first two are necessary to use the API
import asyncio
import BCSz_sync

# The rest of the imports are for the Example program
import time
import random

# for working with images
from PIL import Image
import io
from IPython.display import display # to display images

# for plotting and working with files
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
from numpy import nan

# %% [markdown]
# ## Helper classes and functions for reading data files

# %%
def find_bcs_data(data):
    """
    Keep trying to import the data into pandas until success
    The older BCS scans (so called 'Beamline Scans') have a variably sized header.
    """
    for skrows in range(30):
        data.seek(0)
        try:
            df = pd.read_csv(data, sep='\t', skiprows=skrows, nrows=10)
            df['Time (s)']
            break
        except (pd.errors.ParserError, KeyError):
            pass # try again with skrows +=1

    data.seek(0)
    return skrows


def plot_bcs_file(file_text='', plot_title='', x='Time (s)', y=None):
    """Display example plot for API testing"""
    data = io.StringIO(file_text)
    skip_rows = find_bcs_data(data)
    df = pd.read_csv(data, sep='\t', skiprows=skip_rows)
    print(df.columns)
    df.drop(0, inplace=True)
    print(df.head())

    if not y:
        y = random.choice(df.columns)

    df.plot(kind='scatter', x=x, y=y)
    plt.title(plot_title)
    plt.show()
    return df

# %% [markdown]
# # Connect to BCS server

# %%
bl402bcs = BCSz_sync.BCSServer()

bl402bcs.connect(addr=str(os.environ["BCS_SERVER"]), port=int(os.environ["BCS_PORT"]))
# Out:
# Server Public Key b'Of([HlwK7Q(<)Mni$[J7{%KwFDAEs$RG}7tbIOb&'

# %% [markdown]
# ---
# # PAUSE to check that beamline computer is available for testing
#
# No, seriously!  Ensure that no one else is using the beamline.
#
# ---

# %% [markdown]
# # Scan motors, read data
# ## Careful!!!  This is moving real motors on the beamline

# %% [markdown]
# # Define Ophyd devices for BCS + Bluesky

# %%
from ophyd import Device, Component, Signal
from ophyd.status import DeviceStatus, SubscriptionStatus
from ophyd.flyers import FlyerInterface

# %% [markdown]
# ## Ophyd device for BCS Single Motor Scan

# %%
class BcsSingleMotorScan(Device):
    """
    BCS Single Motor Scan (Move-Delay-Acquire) as an Ophyd device
    """
    
    # Signals to enable subscriptions for scan setup
    motor_name = Component(Signal, kind="config", value='')
    first_value = Component(Signal, kind="config", value=nan)
    last_value = Component(Signal, kind="config", value=nan)
    step_value = Component(Signal, kind="config", value=nan)
    delay_sec = Component(Signal, kind="config", value=0.)
    count_sec = Component(Signal, kind="config", value=1.)
    num_scans = Component(Signal, kind="config", value=1)
    bidirectional = Component(Signal, kind="config", value=False)
    final_move = Component(Signal, kind="config", value="Stay")
    memo = Component(Signal, kind="config", value='')
    filename_pattern = Component(Signal,kind="config", value="*.txt")
    
    # Signals to enable subscriptions/polling for scan status
    ready = Component(Signal, kind="omitted", value=False)
    busy = Component(Signal, kind="omitted", value=False)
    done = Component(Signal, kind="omitted", value=True)
    execute_scan = Component(Signal, kind="omitted", value=True)
    data_path = Component(Signal, kind="normal", value='')


    def scan_setup(
            self, *, 
            # server: str, port: int, 
            bcs_server: BCSz_sync.BCSServer, 
            motor: str, start: float, stop: float, step: float, 
            delay: float = 0., count: float = 1., 
            num_scans: int = 1, bidirect: bool = False, 
            final: str = "Stay",
            memo: str = '',
            filename_pattern: str = "*.txt", 
            **kwargs):
        """Configure a BCS Single Motor Scan"""
        
        # TODO: Check that bcs_server is connected
        self._bcs = bcs_server
        
        self.motor_name.put(motor)
        self.first_value.put(start)
        self.last_value.put(stop)
        self.step_value.put(step)
        self.delay_sec.put(delay)
        self.count_sec.put(count)
        self.num_scans.put(num_scans)
        self.bidirectional.put(bidirect)
        self.final_move.put(final)
        self.memo.put(memo)
        self.filename_pattern.put(filename_pattern)
        
        # Scan is configured and ready to execute
        self.ready.put(True)


    def set(self, value, **kwargs):
        """interface to use bps.mv()"""
        if value != 1:
            return
        if self.ready.get():
            bcs_st = self._bcs.scan_status()
            self.busy.put(bcs_st["running_scan"])
        if (not self.ready.get()) or (self.busy.get()):
            # TODO: Raise Warning that scan is not ready
            return

        async def check_for_acquire_done(self):
            bcs_st = self._bcs.scan_status()
            while bcs_st["running_scan"]:
                await asyncio.sleep(0.1)
                bcs_st = self._bcs.scan_status()
            else:
                # bcs_st = self._bcs.scan_status()
                print("Scan is finshed!")
                # print(f"{bcs_st =}...")
                self.data_path.put(os.path.join(bcs_st["Log Directory"], bcs_st["Last Filename"]))
                # print(f"{self.data_path.get() =}")
                self.done.put(True)
                self.busy.put(False)
                
        def check_value(*, old_value, value, **kwargs):
            "Return True when the acquisition is complete, False otherwise."
            return (value and not old_value)
        
        status = SubscriptionStatus(self.done, check_value)
        
        self.execute_scan.put(True)
        self._bcs.sc_single_motor_scan(
            x_motor=self.motor_name.get(), 
            start=self.first_value.get(), 
            stop=self.last_value.get(), 
            increment=self.step_value.get(), 
            delay_after_move_s=self.delay_sec.get(), 
            count_time_s=self.count_sec.get(), 
            number_of_scans=self.num_scans.get(),
            bidirect=self.bidirectional.get(),
            at_end_of_scan=self.final_move.get(), 
            description=self.memo.get(),
            file_pattern=self.filename_pattern.get(),
            )
        self.busy.put(True)
        self.done.put(False)
        # Give the scanner time to start
        time.sleep(1)  # TODO: Is this needed?
        self.execute_scan.put(False)
        acquire_task = asyncio.create_task(check_for_acquire_done(self))
        # acquire_task.add_done_callback()
        
        return status

# %%
ssM201Roll = BcsSingleMotorScan("BCS402:", name="ssM201Roll")

# %%
ssM201Roll.scan_setup(
        bcs_server=bl402bcs, 
        motor="M201 Roll", start=0., stop=-0.14, step=-0.02, 
        delay=0., count=0.1,
    )

# %%
ssM201Roll.get()
# Out:
# BcsSingleMotorScanTuple(motor_name='M201 Roll', first_value=0.0, last_value=-0.14, step_value=-0.02, delay_sec=0.0, count_sec=0.1, num_scans=1, bidirectional=False, final_move='Stay', memo='', filename_pattern='*.txt', ready=True, busy=False, done=True, execute_scan=True, data_path='')

# %% [markdown]
# ### Usying sycnchronous BCSs library

# %%
ssM201Roll.set(1)
# Out:
# SubscriptionStatus(device=ssM201Roll_done, done=False, success=False)

# %%
# Wait for scan to finish
while ssM201Roll.busy.get():
    await asyncio.sleep(0.5)
    print("...", end=' ')
# Out:
# ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... ... Scan is finshed!
# ...

# %%
ssM201Roll.busy.get()
# Out:
# False

# %%
ssM201Roll.done.get()
# Out:
# True

# %%
ssM201Roll.data_path.get()
# Out:
# 'C:\\Beamline Controls\\BCS Setup Data\\210921\\Single Motor Scan 000050.txt'

# %% [markdown]
# ## Helper functions for converting BCS data to Bluesky event model data

# %%
from bcs_events import *

# %%
from datetime import datetime
import event_model

# %% [markdown]
# ## Ophyd flyer to run BCS Single Motor Scan as a Bluesky "flying" scan

# %%
class BcsSigScanFlyer(FlyerInterface, BcsSingleMotorScan):
    '''Example of BCS Single Motor Scan accessed through Bluesky'''
    
    yield_array_events = Component(Signal, kind="config", value=False)

    def __init__(self, *args, **kwargs):
        self._acquiring = False
        self._paused = False

        super().__init__(*args, **kwargs)
        
    def stage(self):
        super().stage()
        # self.select_channels()

    def unstage(self):
        super().unstage()
        # self.select_channels()

    def read_configuration(self):
        return {}

    def describe_configuration(self):
        return {}

    def kickoff(self):
        """Start the scan."""
        self.stage()
        time.sleep(0.1)

        # Check for currently running scan
        bcs_st = self._bcs.scan_status()
        if bcs_st["running_scan"]:
            raise RuntimeError("Cannot start scan. Another scan is already running.")
        
        self.set(1)
        self._acquiring = True
        self._paused = False

        status = DeviceStatus(self)
        status.set_finished()  # means that kickoff was successful
        return status

    def complete(self):
        """Wait for sscan to complete."""
        logging.info("complete() starting")
        if not self._acquiring:
            raise RuntimeError("Not acquiring")

        # status = DeviceStatus(self)
        # cb_started = False

        def is_scan_complete(*, old_value, value, **kwargs):
            "Return True when the acquisition is complete, False otherwise."
            # value = bool(value)
            if self._acquiring and value and not old_value:
                logging.info("complete() ending")
                self.unstage()
                self._acquiring = False
                return True
            return False

        status = SubscriptionStatus(self.done, is_scan_complete)
        
        return status

    def describe_collect(self):
        """
        Provide schema & meta-data from collect().
        
        http://nsls-ii.github.io/ophyd/generated/ophyd.flyers.FlyerInterface.describe_collect.html
        """
        # TODO: Add hinted signals
        
        ai_names = self._bcs.list_ais()['names']
        
        scan_motor = self.motor_name.get()
        scan_channels = [
            "Time of Day", 
            "Time (s)", 
            f"{scan_motor} Goal", 
            f"{scan_motor} Actual", 
            ] + ai_names
      
        # DataFrame enables convenience functions from 'bcs_events'
        data_df = pd.DataFrame(columns=scan_channels)

        sanitize_event_data_keys = {col: sanitize_key(col) 
            for col in data_df.columns[1:].values}

        descriptor_keys = get_descriptor_keys(
            data_df, 
            sanitize_event_data_keys,
            data_src="Inferred from AI List")
        
        event_stream_name = "primary"
        
        return {event_stream_name: descriptor_keys}

    def collect(self):
        """
        Retrieve all collected data (after complete()).
        
        Retrieve data from the flyer as proto-events.
        http://nsls-ii.github.io/ophyd/generated/ophyd.flyers.FlyerInterface.collect.html
        """
        if self._acquiring:
            raise RuntimeError("Acquisition still in progress. Call complete() first.")
        
        def get_data_from_scan(self):
            """Extract data from scan output file; return as PANDAS DataFrame."""
            file_path = self.data_path.get()
            if not file_path:
                raise RuntimeError("There is no scan data. Call kickoff() first.")
            
            file_text = self._bcs.get_text_file(file_path)['text']

            # Get date from BCS data file header
            with io.StringIO(file_text) as data_file:
                data_file_date_str = data_file.readline().strip().split("Date: ", 1)[1]
                data_date = datetime.strptime(data_file_date_str, "%m/%d/%Y").date()
                self._data_date = data_date
                
            data = io.StringIO(file_text)
            skip_rows = find_bcs_data(data)
            df = pd.read_csv(data, sep='\t', skiprows=skip_rows)
            return df

        def generate_scan_data_events(self):
            """Get the entire scan data and yield bluesky events."""
            data_df = get_data_from_scan(self)
            num_points = len(data_df)
            
            if self.yield_array_events.get():
                raise NotImplementedError("Array events not currently supported")
                # TODO: Implement array event generation

            # Run info will not be used by fly() plan
            # ...enables convenience functions from 'bcs_events'
            run_bundle = event_model.compose_run()
            event_stream_name = 'primary'

            sanitize_event_data_keys = {col: sanitize_key(col) 
                for col in data_df.columns[1:].values}

            descriptor_keys = get_descriptor_keys(
                data_df, 
                sanitize_event_data_keys,
                data_src=self.data_path.get())
    
            stream_descriptor = run_bundle.compose_descriptor(
                data_keys=descriptor_keys,
                name=event_stream_name,
                )

            # Get date from BCS data file header
#             with io.StringIO(self.data_path.get()) as data_file:
#                 data_file_date_str = data_file.readline().strip().split("Date: ", 1)[1]
#                 data_date = datetime.strptime(data_file_date_str, "%m/%d/%Y").date()
            data_date = self._data_date

            # This is only for array events
#             data_df = add_timestamps(data_df, data_date, inplace=True)
#             data_df.drop('Time of Day', axis=1, inplace=True)  # Redundant; have timestamps
#             timestamp_col="timestamp"
    
            data_df = get_timestamps(data_df, data_date, inplace=True)

            def get_bundled_event(data_row):
                return get_event(
                    data_row, sanitize_event_data_keys, stream_descriptor)

            # Pack events into an event_page
            events = data_df.apply(get_bundled_event, axis='columns').values

            # yield 'event_page', event_model.pack_event_page(*events)
            
            for event in events:
                # yield 'event', event
                yield dict(
                    seq_num=event["seq_num"],
                    time=event["time"],
                    data=event["data"],
                    timestamps=event["timestamps"],
                )

        yield from generate_scan_data_events(self)
        self.unstage()

# %%
fly_M201Roll = BcsSigScanFlyer("BCS402:", name="ssflyM201Roll")
fly_M201Roll.scan_setup(
        bcs_server=bl402bcs, 
        motor="M201 Roll", start=0.3, stop=-0.12, step=-0.02, 
        delay=0., count=0.1,
    )

# %%
fly_M201Roll.data_path.put('C:\\Beamline Controls\\BCS Setup Data\\210913\\Single Motor Scan 000033.txt')

# %%
fly_M201Roll.describe_collect()
# Out:
# {'primary': {'Time (s)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'sec'},
#   'M201 Roll Goal': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'M201 Roll Actual': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'I0 BL': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'I0 ES': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'EY': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'LY': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'FY': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'EY SCVM': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'LY SCVM': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'Clock': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Original Clock': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Captured Mono Energy': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'eV'},
#   'Energy': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'eV'},
#   'Polarization': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'Beam Current': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mA'},
#   'Temp A': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'K'},
#   'Temp B': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'K'},
#   'Temp HT': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'K'},
#   'X': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'Y': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'Z': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'Theta': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'degrees'},
#   'M206 Pitch': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'I0 BL Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'I0 ES Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'EY Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'LY Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'FY Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'EY SCVM Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'LY SCVM Amp (nA)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'nA / V'},
#   'EPU Energy': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'eV'},
#   'EPU Gap': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'EPU Phase': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'EPU A': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'EPU B': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'EPU Harmonic': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'Mono Energy': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'eV'},
#   'Grating Posn': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Grating Goal': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Grating Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Premirror Posn': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Premirror Goal': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Premirror Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Premirror Stepper': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Premirror Stepper div 2': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Premirror Encoder': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Grating Stepper': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Grating Stepper div 2': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Grating Encoder': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts'},
#   'Grating Posn Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Premirror Posn Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Jack Posn': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Gate': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'Gate 2': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'EPU Gap from Delta Tau': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'EPU Set Vert Velocity': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm / sec'},
#   'EPU Set Horiz Velocity': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm / sec'},
#   'bl_input': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'bl_input_h': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'A Phase': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'B Phase': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'Captured Grating': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Captured Premirror': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Captured Jack': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Captured EPU Gap': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'mm'},
#   'Goal Premirror': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'OOP Mono Energy': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'eV'},
#   'OOP Grating': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'OOP Premirror': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'OOP Jack': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'OOP Energy Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'eV'},
#   'OOP Grating Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'OOP Premirror Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Goal Premirror Error': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Entrance Slit Width': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'Exit Slit Width': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'um'},
#   'LabVIEW Memory': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'EPU Gap in position': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'EPU Z in position': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'LY SCVM (Original)': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': 'counts / sec'},
#   'C2 U2': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'C2 U3': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'C2 U4': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'C2 U5': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''},
#   'C2 U6': {'dtype': 'number',
#    'source': 'Inferred from AI List',
#    'shape': [],
#    'units': ''}}}

# %%
# for doc_type, doc in fly_M201Roll.collect():
#     print(doc_type)
#     print(doc)

for event_reading in fly_M201Roll.collect():
    print(event_reading)
# Out:
# {'seq_num': 1, 'time': 1632234869.231537, 'data': {'Time (s)': 4.161, 'M201 Roll Goal': 0.0, 'M201 Roll Actual': -0.001, 'I0 BL': 570.0, 'I0 ES': 0.0, 'EY': 1430.0, 'LY': 0.0, 'FY': 0.0, 'EY SCVM': 0.0, 'LY SCVM': 0.0, 'Clock': 100000.0, 'Original Clock': 0.0, 'Captured Mono Energy': 699.98718231, 'Energy': 699.84657908, 'Polarization': 0.0, 'Beam Current': -0.128479, 'Temp A': 0.0, 'Temp B': 0.0, 'Temp HT': 0.0, 'X': -0.5, 'Y': 9.0, 'Z': 0.01492063, 'Theta': -90.002, 'M206 Pitch': 5.76, 'I0 BL Amp (nA)': 1.0, 'I0 ES Amp (nA)': 2.0, 'EY Amp (nA)': 0.2, 'LY Amp (nA)': 0.5, 'FY Amp (nA)': -1000.0, 'EY SCVM Amp (nA)': 5.0, 'LY SCVM Amp (nA)': 5.0, 'EPU Energy': 1984.032, 'EPU Gap': 100.99997187, 'EPU Phase': 0.01600859, 'EPU A': 8.59e-06, 'EPU B': -1.743e-05, 'EPU Harmonic': 3.0, 'Mono Energy': 699.84657908, 'Grating Posn': 29206.25, 'Grating Goal': 29204.60637376, 'Grating Error': 184.5, 'Premirror Posn': 26750.72, 'Premirror Goal': 26750.25360588, 'Premirror Error': -54.5, 'Premirror Stepper': -9889425.0, 'Premirror Stepper div 2': -4944712.5, 'Premirror Encoder': -4944657.0, 'Grating Stepper': -10990781.0, 'Grating Stepper div 2': -5495390.5, 'Grating Encoder': -5495575.0, 'Grating Posn Error': 1.64362624, 'Premirror Posn Error': 0.46639412, 'Jack Posn': -931.68, 'Gate': 0.0, 'Gate 2': 0.0, 'EPU Gap from Delta Tau': 101.0, 'EPU Set Vert Velocity': 3.0, 'EPU Set Horiz Velocity': 16.7, 'bl_input': 99.8834864, 'bl_input_h': 0.01795768, 'A Phase': 8.59e-06, 'B Phase': -1.743e-05, 'Captured Grating': 29205.3520398, 'Captured Premirror': 26751.19960199, 'Captured Jack': -931.68, 'Captured EPU Gap': 101.0, 'Goal Premirror': 26751.10830512, 'OOP Mono Energy': 699.95, 'OOP Grating': 29206.39003111, 'OOP Premirror': 26751.93965133, 'OOP Jack': -931.97526296, 'OOP Energy Error': 0.08718231, 'OOP Grating Error': -2.06133297, 'OOP Premirror Error': -1.55702395, 'Goal Premirror Error': 0.09129687, 'Entrance Slit Width': 40.0, 'Exit Slit Width': 39.9975, 'LabVIEW Memory': 2228536.0, 'EPU Gap in position': 1.0, 'EPU Z in position': 1.0, 'LY SCVM (Original)': 0.0, 'C2 U2': 0.0, 'C2 U3': 0.0, 'C2 U4': 0.0, 'C2 U5': 0.0, 'C2 U6': 0.0}, 'timestamps': {'Time (s)': 1631569263.0, 'M201 Roll Goal': 1631569263.0, 'M201 Roll Actual': 1631569263.0, 'I0 BL': 1631569263.0, 'I0 ES': 1631569263.0, 'EY': 1631569263.0, 'LY': 1631569263.0, 'FY': 1631569263.0, 'EY SCVM': 1631569263.0, 'LY SCVM': 1631569263.0, 'Clock': 1631569263.0, 'Original Clock': 1631569263.0, 'Captured Mono Energy': 1631569263.0, 'Energy': 1631569263.0, 'Polarization': 1631569263.0, 'Beam Current': 1631569263.0, 'Temp A': 1631569263.0, 'Temp B': 1631569263.0, 'Temp HT': 1631569263.0, 'X': 1631569263.0, 'Y': 1631569263.0, 'Z': 1631569263.0, 'Theta': 1631569263.0, 'M206 Pitch': 1631569263.0, 'I0 BL Amp (nA)': 1631569263.0, 'I0 ES Amp (nA)': 1631569263.0, 'EY Amp (nA)': 1631569263.0, 'LY Amp (nA)': 1631569263.0, 'FY Amp (nA)': 1631569263.0, 'EY SCVM Amp (nA)': 1631569263.0, 'LY SCVM Amp (nA)': 1631569263.0, 'EPU Energy': 1631569263.0, 'EPU Gap': 1631569263.0, 'EPU Phase': 1631569263.0, 'EPU A': 1631569263.0, 'EPU B': 1631569263.0, 'EPU Harmonic': 1631569263.0, 'Mono Energy': 1631569263.0, 'Grating Posn': 1631569263.0, 'Grating Goal': 1631569263.0, 'Grating Error': 1631569263.0, 'Premirror Posn': 1631569263.0, 'Premirror Goal': 1631569263.0, 'Premirror Error': 1631569263.0, 'Premirror Stepper': 1631569263.0, 'Premirror Stepper div 2': 1631569263.0, 'Premirror Encoder': 1631569263.0, 'Grating Stepper': 1631569263.0, 'Grating Stepper div 2': 1631569263.0, 'Grating Encoder': 1631569263.0, 'Grating Posn Error': 1631569263.0, 'Premirror Posn Error': 1631569263.0, 'Jack Posn': 1631569263.0, 'Gate': 1631569263.0, 'Gate 2': 1631569263.0, 'EPU Gap from Delta Tau': 1631569263.0, 'EPU Set Vert Velocity': 1631569263.0, 'EPU Set Horiz Velocity': 1631569263.0, 'bl_input': 1631569263.0, 'bl_input_h': 1631569263.0, 'A Phase': 1631569263.0, 'B Phase': 1631569263.0, 'Captured Grating': 1631569263.0, 'Captured Pr ...
# {'seq_num': 2, 'time': 1632234869.2325387, 'data': {'Time (s)': 8.086, 'M201 Roll Goal': -0.02, 'M201 Roll Actual': -0.0195, 'I0 BL': 580.0, 'I0 ES': 0.0, 'EY': 1460.0, 'LY': 0.0, 'FY': 0.0, 'EY SCVM': 0.0, 'LY SCVM': 0.0, 'Clock': 100000.0, 'Original Clock': 0.0, 'Captured Mono Energy': 699.98718231, 'Energy': 699.84457776, 'Polarization': 0.0, 'Beam Current': -0.11576335, 'Temp A': 0.0, 'Temp B': 0.0, 'Temp HT': 0.0, 'X': -0.5, 'Y': 9.0, 'Z': 0.01492063, 'Theta': -90.002, 'M206 Pitch': 5.76, 'I0 BL Amp (nA)': 1.0, 'I0 ES Amp (nA)': 2.0, 'EY Amp (nA)': 0.2, 'LY Amp (nA)': 0.5, 'FY Amp (nA)': -1000.0, 'EY SCVM Amp (nA)': 5.0, 'LY SCVM Amp (nA)': 5.0, 'EPU Energy': 1984.032, 'EPU Gap': 100.99997187, 'EPU Phase': 0.01600859, 'EPU A': 8.59e-06, 'EPU B': -1.743e-05, 'EPU Harmonic': 3.0, 'Mono Energy': 699.84457776, 'Grating Posn': 29206.25, 'Grating Goal': 29204.60637376, 'Grating Error': 184.5, 'Premirror Posn': 26750.68, 'Premirror Goal': 26750.25360588, 'Premirror Error': -55.5, 'Premirror Stepper': -9889425.0, 'Premirror Stepper div 2': -4944712.5, 'Premirror Encoder': -4944661.0, 'Grating Stepper': -10990781.0, 'Grating Stepper div 2': -5495390.5, 'Grating Encoder': -5495575.0, 'Grating Posn Error': 1.64362624, 'Premirror Posn Error': 0.42639412, 'Jack Posn': -931.68, 'Gate': 0.0, 'Gate 2': 0.0, 'EPU Gap from Delta Tau': 101.0, 'EPU Set Vert Velocity': 3.0, 'EPU Set Horiz Velocity': 16.7, 'bl_input': 99.8834864, 'bl_input_h': 0.01795768, 'A Phase': 8.59e-06, 'B Phase': -1.743e-05, 'Captured Grating': 29205.3520398, 'Captured Premirror': 26751.19960199, 'Captured Jack': -931.68, 'Captured EPU Gap': 101.0, 'Goal Premirror': 26751.10830512, 'OOP Mono Energy': 699.95, 'OOP Grating': 29206.39003111, 'OOP Premirror': 26751.93965133, 'OOP Jack': -931.97526296, 'OOP Energy Error': 0.08718231, 'OOP Grating Error': -2.06133297, 'OOP Premirror Error': -1.55702395, 'Goal Premirror Error': 0.09129687, 'Entrance Slit Width': 40.0, 'Exit Slit Width': 39.9975, 'LabVIEW Memory': 2217276.0, 'EPU Gap in position': 1.0, 'EPU Z in position': 1.0, 'LY SCVM (Original)': 0.0, 'C2 U2': 0.0, 'C2 U3': 0.0, 'C2 U4': 0.0, 'C2 U5': 0.0, 'C2 U6': 0.0}, 'timestamps': {'Time (s)': 1631569267.0, 'M201 Roll Goal': 1631569267.0, 'M201 Roll Actual': 1631569267.0, 'I0 BL': 1631569267.0, 'I0 ES': 1631569267.0, 'EY': 1631569267.0, 'LY': 1631569267.0, 'FY': 1631569267.0, 'EY SCVM': 1631569267.0, 'LY SCVM': 1631569267.0, 'Clock': 1631569267.0, 'Original Clock': 1631569267.0, 'Captured Mono Energy': 1631569267.0, 'Energy': 1631569267.0, 'Polarization': 1631569267.0, 'Beam Current': 1631569267.0, 'Temp A': 1631569267.0, 'Temp B': 1631569267.0, 'Temp HT': 1631569267.0, 'X': 1631569267.0, 'Y': 1631569267.0, 'Z': 1631569267.0, 'Theta': 1631569267.0, 'M206 Pitch': 1631569267.0, 'I0 BL Amp (nA)': 1631569267.0, 'I0 ES Amp (nA)': 1631569267.0, 'EY Amp (nA)': 1631569267.0, 'LY Amp (nA)': 1631569267.0, 'FY Amp (nA)': 1631569267.0, 'EY SCVM Amp (nA)': 1631569267.0, 'LY SCVM Amp (nA)': 1631569267.0, 'EPU Energy': 1631569267.0, 'EPU Gap': 1631569267.0, 'EPU Phase': 1631569267.0, 'EPU A': 1631569267.0, 'EPU B': 1631569267.0, 'EPU Harmonic': 1631569267.0, 'Mono Energy': 1631569267.0, 'Grating Posn': 1631569267.0, 'Grating Goal': 1631569267.0, 'Grating Error': 1631569267.0, 'Premirror Posn': 1631569267.0, 'Premirror Goal': 1631569267.0, 'Premirror Error': 1631569267.0, 'Premirror Stepper': 1631569267.0, 'Premirror Stepper div 2': 1631569267.0, 'Premirror Encoder': 1631569267.0, 'Grating Stepper': 1631569267.0, 'Grating Stepper div 2': 1631569267.0, 'Grating Encoder': 1631569267.0, 'Grating Posn Error': 1631569267.0, 'Premirror Posn Error': 1631569267.0, 'Jack Posn': 1631569267.0, 'Gate': 1631569267.0, 'Gate 2': 1631569267.0, 'EPU Gap from Delta Tau': 1631569267.0, 'EPU Set Vert Velocity': 1631569267.0, 'EPU Set Horiz Velocity': 1631569267.0, 'bl_input': 1631569267.0, 'bl_input_h': 1631569267.0, 'A Phase': 1631569267.0, 'B Phase': 1631569267.0, 'Captured Grating': 1631569267.0, 'Captu ...
# {'seq_num': 3, 'time': 1632234869.2325387, 'data': {'Time (s)': 11.877, 'M201 Roll Goal': -0.04, 'M201 Roll Actual': -0.03975, 'I0 BL': 560.0, 'I0 ES': 0.0, 'EY': 1410.0, 'LY': 0.0, 'FY': 0.0, 'EY SCVM': 0.0, 'LY SCVM': 0.0, 'Clock': 100000.0, 'Original Clock': 0.0, 'Captured Mono Energy': 699.98718231, 'Energy': 699.84426097, 'Polarization': 0.0, 'Beam Current': -0.12975057, 'Temp A': 0.0, 'Temp B': 0.0, 'Temp HT': 0.0, 'X': -0.5, 'Y': 9.0, 'Z': 0.01492063, 'Theta': -90.002, 'M206 Pitch': 5.76, 'I0 BL Amp (nA)': 1.0, 'I0 ES Amp (nA)': 2.0, 'EY Amp (nA)': 0.2, 'LY Amp (nA)': 0.5, 'FY Amp (nA)': -1000.0, 'EY SCVM Amp (nA)': 5.0, 'LY SCVM Amp (nA)': 5.0, 'EPU Energy': 1984.032, 'EPU Gap': 100.99997187, 'EPU Phase': 0.01600859, 'EPU A': 8.59e-06, 'EPU B': -1.743e-05, 'EPU Harmonic': 3.0, 'Mono Energy': 699.84426097, 'Grating Posn': 29206.25, 'Grating Goal': 29204.60637376, 'Grating Error': 184.5, 'Premirror Posn': 26750.71, 'Premirror Goal': 26750.25360588, 'Premirror Error': -51.5, 'Premirror Stepper': -9889425.0, 'Premirror Stepper div 2': -4944712.5, 'Premirror Encoder': -4944658.0, 'Grating Stepper': -10990781.0, 'Grating Stepper div 2': -5495390.5, 'Grating Encoder': -5495575.0, 'Grating Posn Error': 1.64362624, 'Premirror Posn Error': 0.45639412, 'Jack Posn': -931.68, 'Gate': 0.0, 'Gate 2': 0.0, 'EPU Gap from Delta Tau': 101.0, 'EPU Set Vert Velocity': 3.0, 'EPU Set Horiz Velocity': 16.7, 'bl_input': 99.8834864, 'bl_input_h': 0.01795768, 'A Phase': 8.59e-06, 'B Phase': -1.743e-05, 'Captured Grating': 29205.3520398, 'Captured Premirror': 26751.19960199, 'Captured Jack': -931.68, 'Captured EPU Gap': 101.0, 'Goal Premirror': 26751.10830512, 'OOP Mono Energy': 699.95, 'OOP Grating': 29206.39003111, 'OOP Premirror': 26751.93965133, 'OOP Jack': -931.97526296, 'OOP Energy Error': 0.08718231, 'OOP Grating Error': -2.06133297, 'OOP Premirror Error': -1.55702395, 'Goal Premirror Error': 0.09129687, 'Entrance Slit Width': 40.0, 'Exit Slit Width': 39.9975, 'LabVIEW Memory': 2228524.0, 'EPU Gap in position': 1.0, 'EPU Z in position': 1.0, 'LY SCVM (Original)': 0.0, 'C2 U2': 0.0, 'C2 U3': 0.0, 'C2 U4': 0.0, 'C2 U5': 0.0, 'C2 U6': 0.0}, 'timestamps': {'Time (s)': 1631569271.0, 'M201 Roll Goal': 1631569271.0, 'M201 Roll Actual': 1631569271.0, 'I0 BL': 1631569271.0, 'I0 ES': 1631569271.0, 'EY': 1631569271.0, 'LY': 1631569271.0, 'FY': 1631569271.0, 'EY SCVM': 1631569271.0, 'LY SCVM': 1631569271.0, 'Clock': 1631569271.0, 'Original Clock': 1631569271.0, 'Captured Mono Energy': 1631569271.0, 'Energy': 1631569271.0, 'Polarization': 1631569271.0, 'Beam Current': 1631569271.0, 'Temp A': 1631569271.0, 'Temp B': 1631569271.0, 'Temp HT': 1631569271.0, 'X': 1631569271.0, 'Y': 1631569271.0, 'Z': 1631569271.0, 'Theta': 1631569271.0, 'M206 Pitch': 1631569271.0, 'I0 BL Amp (nA)': 1631569271.0, 'I0 ES Amp (nA)': 1631569271.0, 'EY Amp (nA)': 1631569271.0, 'LY Amp (nA)': 1631569271.0, 'FY Amp (nA)': 1631569271.0, 'EY SCVM Amp (nA)': 1631569271.0, 'LY SCVM Amp (nA)': 1631569271.0, 'EPU Energy': 1631569271.0, 'EPU Gap': 1631569271.0, 'EPU Phase': 1631569271.0, 'EPU A': 1631569271.0, 'EPU B': 1631569271.0, 'EPU Harmonic': 1631569271.0, 'Mono Energy': 1631569271.0, 'Grating Posn': 1631569271.0, 'Grating Goal': 1631569271.0, 'Grating Error': 1631569271.0, 'Premirror Posn': 1631569271.0, 'Premirror Goal': 1631569271.0, 'Premirror Error': 1631569271.0, 'Premirror Stepper': 1631569271.0, 'Premirror Stepper div 2': 1631569271.0, 'Premirror Encoder': 1631569271.0, 'Grating Stepper': 1631569271.0, 'Grating Stepper div 2': 1631569271.0, 'Grating Encoder': 1631569271.0, 'Grating Posn Error': 1631569271.0, 'Premirror Posn Error': 1631569271.0, 'Jack Posn': 1631569271.0, 'Gate': 1631569271.0, 'Gate 2': 1631569271.0, 'EPU Gap from Delta Tau': 1631569271.0, 'EPU Set Vert Velocity': 1631569271.0, 'EPU Set Horiz Velocity': 1631569271.0, 'bl_input': 1631569271.0, 'bl_input_h': 1631569271.0, 'A Phase': 1631569271.0, 'B Phase': 1631569271.0, 'Captured Grating': 1631569271.0, 'Cap ...
# {'seq_num': 4, 'time': 1632234869.2335382, 'data': {'Time (s)': 15.626, 'M201 Roll Goal': -0.06, 'M201 Roll Actual': -0.06, 'I0 BL': 570.0, 'I0 ES': 0.0, 'EY': 1440.0, 'LY': 0.0, 'FY': 0.0, 'EY SCVM': 0.0, 'LY SCVM': 0.0, 'Clock': 100001.0, 'Original Clock': 0.0, 'Captured Mono Energy': 699.98718231, 'Energy': 699.84559517, 'Polarization': 0.0, 'Beam Current': -0.128479, 'Temp A': 0.0, 'Temp B': 0.0, 'Temp HT': 0.0, 'X': -0.5, 'Y': 9.0, 'Z': 0.01492063, 'Theta': -90.002, 'M206 Pitch': 5.76, 'I0 BL Amp (nA)': 1.0, 'I0 ES Amp (nA)': 2.0, 'EY Amp (nA)': 0.2, 'LY Amp (nA)': 0.5, 'FY Amp (nA)': -1000.0, 'EY SCVM Amp (nA)': 5.0, 'LY SCVM Amp (nA)': 5.0, 'EPU Energy': 1984.032, 'EPU Gap': 100.99997187, 'EPU Phase': 0.01600859, 'EPU A': 8.59e-06, 'EPU B': -1.743e-05, 'EPU Harmonic': 3.0, 'Mono Energy': 699.84559517, 'Grating Posn': 29206.25, 'Grating Goal': 29204.60637376, 'Grating Error': 184.5, 'Premirror Posn': 26750.71, 'Premirror Goal': 26750.25360588, 'Premirror Error': -54.5, 'Premirror Stepper': -9889425.0, 'Premirror Stepper div 2': -4944712.5, 'Premirror Encoder': -4944658.0, 'Grating Stepper': -10990781.0, 'Grating Stepper div 2': -5495390.5, 'Grating Encoder': -5495575.0, 'Grating Posn Error': 1.64362624, 'Premirror Posn Error': 0.45639412, 'Jack Posn': -931.68, 'Gate': 0.0, 'Gate 2': 0.0, 'EPU Gap from Delta Tau': 101.0, 'EPU Set Vert Velocity': 3.0, 'EPU Set Horiz Velocity': 16.7, 'bl_input': 99.8834864, 'bl_input_h': 0.01795768, 'A Phase': 8.59e-06, 'B Phase': -1.743e-05, 'Captured Grating': 29205.3520398, 'Captured Premirror': 26751.19960199, 'Captured Jack': -931.68, 'Captured EPU Gap': 101.0, 'Goal Premirror': 26751.10830512, 'OOP Mono Energy': 699.95, 'OOP Grating': 29206.39003111, 'OOP Premirror': 26751.93965133, 'OOP Jack': -931.97526296, 'OOP Energy Error': 0.08718231, 'OOP Grating Error': -2.06133297, 'OOP Premirror Error': -1.55702395, 'Goal Premirror Error': 0.09129687, 'Entrance Slit Width': 40.0, 'Exit Slit Width': 39.9975, 'LabVIEW Memory': 2217260.0, 'EPU Gap in position': 1.0, 'EPU Z in position': 1.0, 'LY SCVM (Original)': 0.0, 'C2 U2': 0.0, 'C2 U3': 0.0, 'C2 U4': 0.0, 'C2 U5': 0.0, 'C2 U6': 0.0}, 'timestamps': {'Time (s)': 1631569275.0, 'M201 Roll Goal': 1631569275.0, 'M201 Roll Actual': 1631569275.0, 'I0 BL': 1631569275.0, 'I0 ES': 1631569275.0, 'EY': 1631569275.0, 'LY': 1631569275.0, 'FY': 1631569275.0, 'EY SCVM': 1631569275.0, 'LY SCVM': 1631569275.0, 'Clock': 1631569275.0, 'Original Clock': 1631569275.0, 'Captured Mono Energy': 1631569275.0, 'Energy': 1631569275.0, 'Polarization': 1631569275.0, 'Beam Current': 1631569275.0, 'Temp A': 1631569275.0, 'Temp B': 1631569275.0, 'Temp HT': 1631569275.0, 'X': 1631569275.0, 'Y': 1631569275.0, 'Z': 1631569275.0, 'Theta': 1631569275.0, 'M206 Pitch': 1631569275.0, 'I0 BL Amp (nA)': 1631569275.0, 'I0 ES Amp (nA)': 1631569275.0, 'EY Amp (nA)': 1631569275.0, 'LY Amp (nA)': 1631569275.0, 'FY Amp (nA)': 1631569275.0, 'EY SCVM Amp (nA)': 1631569275.0, 'LY SCVM Amp (nA)': 1631569275.0, 'EPU Energy': 1631569275.0, 'EPU Gap': 1631569275.0, 'EPU Phase': 1631569275.0, 'EPU A': 1631569275.0, 'EPU B': 1631569275.0, 'EPU Harmonic': 1631569275.0, 'Mono Energy': 1631569275.0, 'Grating Posn': 1631569275.0, 'Grating Goal': 1631569275.0, 'Grating Error': 1631569275.0, 'Premirror Posn': 1631569275.0, 'Premirror Goal': 1631569275.0, 'Premirror Error': 1631569275.0, 'Premirror Stepper': 1631569275.0, 'Premirror Stepper div 2': 1631569275.0, 'Premirror Encoder': 1631569275.0, 'Grating Stepper': 1631569275.0, 'Grating Stepper div 2': 1631569275.0, 'Grating Encoder': 1631569275.0, 'Grating Posn Error': 1631569275.0, 'Premirror Posn Error': 1631569275.0, 'Jack Posn': 1631569275.0, 'Gate': 1631569275.0, 'Gate 2': 1631569275.0, 'EPU Gap from Delta Tau': 1631569275.0, 'EPU Set Vert Velocity': 1631569275.0, 'EPU Set Horiz Velocity': 1631569275.0, 'bl_input': 1631569275.0, 'bl_input_h': 1631569275.0, 'A Phase': 1631569275.0, 'B Phase': 1631569275.0, 'Captured Grating': 1631569275.0, 'Captured ...
# {'seq_num': 5, 'time': 1632234869.2345352, 'data': {'Time (s)': 19.468, 'M201 Roll Goal': -0.08, 'M201 Roll Actual': -0.08, 'I0 BL': 570.0, 'I0 ES': 0.0, 'EY': 1390.0, 'LY': 0.0, 'FY': 0.0, 'EY SCVM': 0.0, 'LY SCVM': 0.0, 'Clock': 100000.0, 'Original Clock': 0.0, 'Captured Mono Energy': 699.98718231, 'Energy': 699.84524486, 'Polarization': 0.0, 'Beam Current': -0.12975057, 'Temp A': 0.0, 'Temp B': 0.0, 'Temp HT': 0.0, 'X': -0.5, 'Y': 9.0, 'Z': 0.01492063, 'Theta': -90.002, 'M206 Pitch': 5.76, 'I0 BL Amp (nA)': 1.0, 'I0 ES Amp (nA)': 2.0, 'EY Amp (nA)': 0.2, 'LY Amp (nA)': 0.5, 'FY Amp (nA)': -1000.0, 'EY SCVM Amp (nA)': 5.0, 'LY SCVM Amp (nA)': 5.0, 'EPU Energy': 1984.032, 'EPU Gap': 100.99997187, 'EPU Phase': 0.01600859, 'EPU A': 8.59e-06, 'EPU B': -1.743e-05, 'EPU Harmonic': 3.0, 'Mono Energy': 699.84524486, 'Grating Posn': 29206.25, 'Grating Goal': 29204.60637376, 'Grating Error': 184.5, 'Premirror Posn': 26750.73, 'Premirror Goal': 26750.25360588, 'Premirror Error': -54.5, 'Premirror Stepper': -9889425.0, 'Premirror Stepper div 2': -4944712.5, 'Premirror Encoder': -4944656.0, 'Grating Stepper': -10990781.0, 'Grating Stepper div 2': -5495390.5, 'Grating Encoder': -5495575.0, 'Grating Posn Error': 1.64362624, 'Premirror Posn Error': 0.47639412, 'Jack Posn': -931.68, 'Gate': 0.0, 'Gate 2': 0.0, 'EPU Gap from Delta Tau': 101.0, 'EPU Set Vert Velocity': 3.0, 'EPU Set Horiz Velocity': 16.7, 'bl_input': 99.8834864, 'bl_input_h': 0.01795768, 'A Phase': 8.59e-06, 'B Phase': -1.743e-05, 'Captured Grating': 29205.3520398, 'Captured Premirror': 26751.19960199, 'Captured Jack': -931.68, 'Captured EPU Gap': 101.0, 'Goal Premirror': 26751.10830512, 'OOP Mono Energy': 699.95, 'OOP Grating': 29206.39003111, 'OOP Premirror': 26751.93965133, 'OOP Jack': -931.97526296, 'OOP Energy Error': 0.08718231, 'OOP Grating Error': -2.06133297, 'OOP Premirror Error': -1.55702395, 'Goal Premirror Error': 0.09129687, 'Entrance Slit Width': 40.0, 'Exit Slit Width': 39.9975, 'LabVIEW Memory': 2228532.0, 'EPU Gap in position': 1.0, 'EPU Z in position': 1.0, 'LY SCVM (Original)': 0.0, 'C2 U2': 0.0, 'C2 U3': 0.0, 'C2 U4': 0.0, 'C2 U5': 0.0, 'C2 U6': 0.0}, 'timestamps': {'Time (s)': 1631569279.0, 'M201 Roll Goal': 1631569279.0, 'M201 Roll Actual': 1631569279.0, 'I0 BL': 1631569279.0, 'I0 ES': 1631569279.0, 'EY': 1631569279.0, 'LY': 1631569279.0, 'FY': 1631569279.0, 'EY SCVM': 1631569279.0, 'LY SCVM': 1631569279.0, 'Clock': 1631569279.0, 'Original Clock': 1631569279.0, 'Captured Mono Energy': 1631569279.0, 'Energy': 1631569279.0, 'Polarization': 1631569279.0, 'Beam Current': 1631569279.0, 'Temp A': 1631569279.0, 'Temp B': 1631569279.0, 'Temp HT': 1631569279.0, 'X': 1631569279.0, 'Y': 1631569279.0, 'Z': 1631569279.0, 'Theta': 1631569279.0, 'M206 Pitch': 1631569279.0, 'I0 BL Amp (nA)': 1631569279.0, 'I0 ES Amp (nA)': 1631569279.0, 'EY Amp (nA)': 1631569279.0, 'LY Amp (nA)': 1631569279.0, 'FY Amp (nA)': 1631569279.0, 'EY SCVM Amp (nA)': 1631569279.0, 'LY SCVM Amp (nA)': 1631569279.0, 'EPU Energy': 1631569279.0, 'EPU Gap': 1631569279.0, 'EPU Phase': 1631569279.0, 'EPU A': 1631569279.0, 'EPU B': 1631569279.0, 'EPU Harmonic': 1631569279.0, 'Mono Energy': 1631569279.0, 'Grating Posn': 1631569279.0, 'Grating Goal': 1631569279.0, 'Grating Error': 1631569279.0, 'Premirror Posn': 1631569279.0, 'Premirror Goal': 1631569279.0, 'Premirror Error': 1631569279.0, 'Premirror Stepper': 1631569279.0, 'Premirror Stepper div 2': 1631569279.0, 'Premirror Encoder': 1631569279.0, 'Grating Stepper': 1631569279.0, 'Grating Stepper div 2': 1631569279.0, 'Grating Encoder': 1631569279.0, 'Grating Posn Error': 1631569279.0, 'Premirror Posn Error': 1631569279.0, 'Jack Posn': 1631569279.0, 'Gate': 1631569279.0, 'Gate 2': 1631569279.0, 'EPU Gap from Delta Tau': 1631569279.0, 'EPU Set Vert Velocity': 1631569279.0, 'EPU Set Horiz Velocity': 1631569279.0, 'bl_input': 1631569279.0, 'bl_input_h': 1631569279.0, 'A Phase': 1631569279.0, 'B Phase': 1631569279.0, 'Captured Grating': 1631569279.0, 'Captur ...

# %% [markdown]
# ### Run the Bluesky flying plan

# %%
fly_M201Roll = BcsSigScanFlyer("BCS402:", name="ssflyM201Roll")

# %%
fly_M201Roll.scan_setup(
        bcs_server=bl402bcs, 
        motor="M201 Roll", start=0.3, stop=-0.3, step=-0.02, 
        delay=0., count=0.1,
    )

# %%
fly_M201Roll.get()
# Out:
# BcsSigScanFlyerTuple(motor_name='M201 Roll', first_value=0.3, last_value=-0.3, step_value=-0.02, delay_sec=0.0, count_sec=0.1, num_scans=1, bidirectional=False, final_move='Stay', memo='', filename_pattern='*.txt', ready=True, busy=False, done=True, execute_scan=True, data_path='', yield_array_events=False)

# %%
from bluesky.plans import fly

RE(fly([fly_M201Roll], md=dict(purpose="demo bluesky fly plan with BCS Single Motor step scan")))
# Out:
# Transient Scan ID: 1     Time: 2021-09-21 07:34:34
# Persistent Unique Scan ID: '1d1fc7f8-a638-452d-b399-e6b3aeaf643d'
# INFO:root:complete() starting
# ssflyM201Roll_done [In progress. No progress bar available.]
# Scan is finshed!
# INFO:root:complete() ending
# ssflyM201Roll_done [In progress. No progress bar available.]
#
# New stream: 'primary'
# +-----------+------------+
# |   seq_num |       time |
# +-----------+------------+
# C:\Users\admin\miniconda3\envs\bluesky\lib\site-packages\event_model\__init__.py:208: UserWarning: The document type 'bulk_events' has been deprecated in favor of 'event_page', whose structure is a transpose of 'bulk_events'.
#   warnings.warn(
# +-----------+------------+
# generator fly ['1d1fc7f8'] (scan num: 1)
# INFO:bluesky.RE.state:Change state on <bluesky.run_engine.RunEngine object at 0x0000020E13875EE0> from 'running' -> 'idle'
# INFO:bluesky:Cleaned up from plan <generator object fly at 0x0000020E1D3A12E0>
# ('1d1fc7f8-a638-452d-b399-e6b3aeaf643d',)

# %%
fly_M201Roll.busy.get()
fly_M201Roll.done.get()
fly_M201Roll.data_path.get()
# Out:
# False
# True
# 'C:\\Beamline Controls\\BCS Setup Data\\210921\\Single Motor Scan 000051.txt'

# %%
run = db.v2[-1]
data = run.primary.read()
data.plot.scatter("M201 Roll Actual", "I0 BL")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data.plot.scatter("M201 Roll Goal", "M201 Roll Actual")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(
    data["M201 Roll Goal"], 
    data["M201 Roll Actual"] - data["M201 Roll Goal"],
    );
plt.xlabel("M201 Roll Goal");
plt.ylabel("M201 Roll Error");
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'M201 Roll Goal')
# Text(0, 0.5, 'M201 Roll Error')

# %% [markdown]
# # Which control layer is ophyd using

# %%
from ophyd import cl

cl
# Out:
# namespace(setup=<function ophyd._pyepics_shim.setup(logger)>,
#           caput=<function epics.caput(pvname, value, wait=False, timeout=60)>,
#           caget=<function epics.caget(pvname, as_string=False, count=None, as_numpy=True, use_monitor=False, timeout=5.0)>,
#           get_pv=<function epics.pv.get_pv(pvname, form='time', connect=False, context=None, timeout=5.0, connection_callback=None, access_callback=None, callback=None, verbose=False, count=None, auto_monitor=None)>,
#           thread_class=epics.ca.CAThread,
#           name='pyepics',
#           release_pvs=<function ophyd._pyepics_shim.release_pvs(*pvs)>,
#           get_dispatcher=<function ophyd._pyepics_shim.get_dispatcher()>)
